# %% [markdown]
# # Data Extraction sur Python
#
# ## 1. Extraction d'un fichier CSV
#
# Base de données des brevets de l’INPI. Chaque brevet est géo-localisés à différents niveaux selon l'adresse des déposants et des inventeurs : pays, régions, départements, unités urbaines, communes.
# Source: https://drive.google.com/file/d/1sJysh-DSbystXz6rVz-nEzx4uQJZQhgN/view

# %%
import pandas as pd

patents = pd.read_csv('fr-esr-brevets-france-inpi-oeb.csv', delimiter=";")
patents.head()
# Out:
#   num_depot origine  annees_publication  annees_delivrance part  \
# 0   1161944  France                2013             2013.0  Non
# 1   0400729  France                2005             2006.0  Non
# 2   0512601  France                2007                NaN  Non
# 3   1150006  France                2012             2014.0  Non
# 4   1101373  France                2012             2014.0  Non
#
#                         type_d_tablissement  num_siren    id_dep     com_code  \
# 0                    Grande Entreprise (GE)  632012100     49478        75108
# 1                         Personne physique        NaN     12620        35238
# 2                         Personne physique        NaN     15837        91477
# 3       Personne physique;Personne physique        NaN  489;7548  69034,69034
# 4  Entreprise de taille Intermédiaire (ETI)  394342299     37732        94021
#
#                              com_nom  ...  \
# 0                          Paris  8e  ...
# 1                             Rennes  ...
# 2                          Palaiseau  ...
# 3  Caluire-et-Cuire,Caluire-et-Cuire  ...
# 4                     Chevilly-Larue  ...
#
#                                   type  \
# 0                      Personne morale
# 1                    Personne physique
# 2                    Personne physique
# 3  Personne physique;Personne physique
# 4                      Personne morale
#
#                                        etab      domaine_technologique  \
# 0                    Grande Entreprise (GE)                     Chimie
# 1                         Personne physique                     Chimie
# 2                         Personne physique  Electronique, électricité
# 3       Personne physique;Personne physique                     Autres
# 4  Entreprise de taille Intermédiaire (ETI)            Instrumentation
#
#                sous_domaine_technologique              nom brev_de de_libelle  \
# 0                   Chimie organique fine          L'oreal     Non        NaN
# 1                      Chimie alimentaire          delerue     Non        NaN
# 2  Transmission d’informations numériques         gauthier     Oui        TIC
# 3                                     BTP  BERNARD;bernard     Non        NaN
# 4                    Techniques de mesure              Aer     Oui        TIC
#
#        de_sd1_libelle de_sd2_libelle fe_id
# 0                 NaN            NaN   FE1
# 1                 NaN            NaN   FE1
# 2  Télécommunications            NaN   FE1
# 3                 NaN            NaN   FE1
# 4          Autres TIC            NaN   FE1
#
# [5 rows x 44 columns]

# %%
# Supprimer les quatres dernières colonnes
patents.drop('de_libelle', inplace=True, axis=1)
patents.drop('de_sd1_libelle', inplace=True, axis=1)
patents.drop('de_sd2_libelle', inplace=True, axis=1)
patents.drop('fe_id', inplace=True, axis=1)
patents.head()
# Out:
#   num_depot origine  annees_publication  annees_delivrance part  \
# 0   1161944  France                2013             2013.0  Non
# 1   0400729  France                2005             2006.0  Non
# 2   0512601  France                2007                NaN  Non
# 3   1150006  France                2012             2014.0  Non
# 4   1101373  France                2012             2014.0  Non
#
#                         type_d_tablissement  num_siren    id_dep     com_code  \
# 0                    Grande Entreprise (GE)  632012100     49478        75108
# 1                         Personne physique        NaN     12620        35238
# 2                         Personne physique        NaN     15837        91477
# 3       Personne physique;Personne physique        NaN  489;7548  69034,69034
# 4  Entreprise de taille Intermédiaire (ETI)  394342299     37732        94021
#
#                              com_nom  ...  \
# 0                          Paris  8e  ...
# 1                             Rennes  ...
# 2                          Palaiseau  ...
# 3  Caluire-et-Cuire,Caluire-et-Cuire  ...
# 4                     Chevilly-Larue  ...
#
#                                       region  code_region_inv  \
# 0                              Ile-de-France  R11,R11,R11,R11
# 1                                   Bretagne              R53
# 2                              Ile-de-France              R11
# 3  Auvergne-Rhône-Alpes,Auvergne-Rhône-Alpes              R84
# 4                              Ile-de-France              R11
#
#                                           region_inv  \
# 0  Ile-de-France,Ile-de-France,Ile-de-France,Ile-...
# 1                                           Bretagne
# 2                                      Ile-de-France
# 3                               Auvergne-Rhône-Alpes
# 4                                      Ile-de-France
#
#                                secteur                                 type  \
# 0                                Privé                      Personne morale
# 1                    Personne physique                    Personne physique
# 2                    Personne physique                    Personne physique
# 3  Personne physique;Personne physique  Personne physique;Personne physique
# 4                                Privé                      Personne morale
#
#                                        etab      domaine_technologique  \
# 0                    Grande Entreprise (GE)                     Chimie
# 1                         Personne physique                     Chimie
# 2                         Personne physique  Electronique, électricité
# 3       Personne physique;Personne physique                     Autres
# 4  Entreprise de taille Intermédiaire (ETI)            Instrumentation
#
#                sous_domaine_technologique              nom brev_de
# 0                   Chimie organique fine          L'oreal     Non
# 1                      Chimie alimentaire          delerue     Non
# 2  Transmission d’informations numériques         gauthier     Oui
# 3                                     BTP  BERNARD;bernard     Non
# 4                    Techniques de mesure              Aer     Oui
#
# [5 rows x 40 columns]

# %% [markdown]
# ## 2. Extraction d'un fichier JSON
#
# Base de données: Panorama des festivals en PACA.
# Source: https://trouver.datasud.fr/dataset/panorama-des-festivals

# %%
json_file = pd.read_json('panorama-des-festivals.json')
festivals = pd.DataFrame(json_file['fields'].tolist())
festivals.head()
# Out:
#    dept_sk               coordonnees_insee date_de_fin_ancien  \
# 0     13.0   [43.5502689105, 4.9511813524]         2019-02-10
# 1     13.0  [43.2999009436, 5.38227869795]         2019-03-31
# 2     13.0  [43.2999009436, 5.38227869795]         2019-03-31
# 3     83.0  [43.1361589728, 5.93239634249]         2019-03-09
# 4     13.0  [43.2934843764, 5.56331273477]         2019-03-23
#
#    mois_indicatif_en_chiffre_y_compris_double_mois   nom_departement  \
# 0                                              2.0  Bouches-du-Rhône
# 1                                              2.0  Bouches-du-Rhône
# 2                                              3.0  Bouches-du-Rhône
# 3                                              3.0               Var
# 4                                              3.0  Bouches-du-Rhône
#
#   departement periodicite mois_habituel_de_debut code_postal  \
# 0          13    Annuelle           02 (février)       13118
# 1          13    Annuelle           02 (février)       13001
# 2          13         NaN              03 (mars)       13001
# 3          83    Annuelle              03 (mars)       83200
# 4          13    Annuelle              03 (mars)       13400
#
#                      complement_domaine  ... ndeg_de_l_edition_2018  \
# 0                                Cirque  ...                   20.0
# 1                     Baroque et ancien  ...                   16.0
# 2   Jazz, blues et musiques improvisées  ...                    NaN
# 3  Musiques amplifiées ou électroniques  ...                    1.0
# 4                                   NaN  ...                   19.0
#
#   ndeg_de_l_edition_2019                autres_communes  \
# 0                   21.0                            NaN
# 1                   17.0  Saint Mitre les Remparts (13)
# 2                    NaN                            NaN
# 3                    2.0                            NaN
# 4                   20.0                            NaN
#
#                                         commentaires  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  2ème édition. Festival exclusivement dédié au ...
# 4                                                NaN
#
#   soutenu_en_2017_par_le_ministere_de_la_culture  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            oui
#
#   soutenu_en_2017_par_le_centre_national_du_cinema  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              oui
#
#   soutenu_en_2017_par_le_centre_national_du_livre  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   soutenu_en_2017_par_le_centre_national_des_varietes mois_indicatif  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#   soutenu_en_2018_par_le_ministere_de_la_culture
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# [5 rows x 31 columns]

# %%
# Combien y-a-t-il de festivals en PACA ?
total_festivals = len(festivals)
print(f"Il y a {total_festivals} festivals en Provence-Alpes-Côte d'Azur.")
# Out:
# Il y a 319 festivals en Provence-Alpes-Côte d'Azur.

# %%
# Quelles sont les 3 villes qui accueillent la majorité des festivals ?
city_counts = festivals.groupby('commune_principale').size().reset_index(name='count')
city_counts = city_counts.sort_values(by='count', ascending=False)
most_festivals_city1 = city_counts.iloc[0]['commune_principale']
most_festivals_city2 = city_counts.iloc[1]['commune_principale']
most_festivals_city3 = city_counts.iloc[2]['commune_principale']
print(f"Les 3 villes avec le plus de festivals sont {most_festivals_city1}, {most_festivals_city2} et {most_festivals_city3}.")
# Out:
# Les 3 villes avec le plus de festivals sont MARSEILLE, CANNES et AVIGNON.

# %%
# Quel est le mois de l'année le plus chargé en festivals ?
month_counts = festivals.groupby('mois_habituel_de_debut').size().reset_index(name='count')
month_counts = month_counts.sort_values(by='count', ascending=False)
most_festivals_month = month_counts.iloc[0]['mois_habituel_de_debut']
print(f"Le mois avec le plus de festivals est {most_festivals_month}.")
# Out:
# Le mois avec le plus de festivals est 07 (juillet).

# %% [markdown]
# ## 3. Extraction depuis une base de données
#
# Base de données contenant les clients, comptes et opérations d'une banque fictive.
# Source: http://alain.troesch.free.fr/2017/Fichiers/py066-ma_banque.db

# %%
# Installer puis importer le connecteur (ex : 'mysql.connector' ou 'sqlite3') :
import sqlite3

# Se connecter à la base de données en inscrivant la bonne configuration :
bank_db = sqlite3.connect('py066-ma_banque.db')

# Extraire des données à partir de la base :

# Méthode 1 : Utilisation du curseur et renvoi d'un tuple
cursor = bank_db.cursor()
cursor.execute("SELECT nom, prenom, ville FROM client WHERE idclient = ?", ("1", ))
client1 = cursor.fetchone()
print(client1)

# Méthode 2 : Utilisation de 'read_sql_query' et renvoi d'un dataframe
query = '''
SELECT nom, prenom, ville
FROM client
WHERE idclient = "1"
'''
client2 = pd.read_sql_query(query, bank_db)
client2

# Fermer la connexion (après avoir effectué toutes les requêtes):
# bank_db.close()
# Out:
# ('Ewing', 'Grant', 'Strasbourg')
#      nom prenom       ville
# 0  Ewing  Grant  Strasbourg

# %%
# 1. Donner le nom et le prénom de tous les clients.
query = '''
SELECT nom, prenom FROM client
'''
q1 = pd.read_sql_query(query, bank_db)
q1
# Out:
#         nom    prenom
# 0     Ewing     Grant
# 1      Buck    Violet
# 2      Hood  Isabelle
# 3     Small   Germane
# 4   Hancock   Vincent
# ..      ...       ...
# 95     Koch     Alexa
# 96   Sparks      Nina
# 97  Mathews      Elmo
# 98   Slater   Donovan
# 99   Sparks     Steel
#
# [100 rows x 2 columns]

# %%
# 2. Donner le nom et le prénom des clients habitant à Paris.
query = '''
SELECT nom, prenom FROM client WHERE ville = "Paris"
'''
q2 = pd.read_sql_query(query, bank_db)
q2
# Out:
#        nom       prenom
# 0     Hood     Isabelle
# 1  Parsons        Leroy
# 2    Grant     Prescott
# 3     Hill       Olivia
# 4      Fry       Sierra
# 5   Becker  Buckminster

# %%
# 3. Donner les identifiants des comptes de type Livret A.
cursor.execute("SELECT idcompte FROM compte WHERE type = 'Livret A'")
q3 = cursor.fetchall()
print(q3)
# Out:
# [(2,), (10,), (11,), (13,), (28,), (30,), (31,), (37,), (45,), (51,), (52,), (53,), (59,), (61,), (64,), (69,), (72,), (77,), (89,), (94,), (98,), (101,), (102,), (106,), (117,), (120,), (122,), (125,), (126,), (127,), (128,), (130,), (139,), (144,), (148,), (156,), (159,), (162,), (165,), (166,), (169,), (170,), (172,), (177,), (181,), (188,), (190,), (192,), (196,), (198,), (201,), (203,), (213,), (214,), (224,), (225,), (228,), (229,), (230,), (231,), (235,), (236,), (237,), (239,), (256,), (269,), (273,), (278,), (282,), (295,), (297,), (299,)]

# %%
# 4. Donner les identifiants des opérations de débit sur le compte d’identifiant égal à 1.
cursor.execute("SELECT idop FROM operation WHERE idcompte = '1'")
q4 = cursor.fetchall()
print(q4)
# Out:
# [(582,), (650,), (722,), (836,)]

# %%
# 5. Donner, sans doublon, les identifiants des propriétaires de livret A, classés par ordre croissant.
cursor.execute("SELECT DISTINCT idproprietaire FROM compte WHERE type = 'Livret A' ORDER BY idproprietaire")
q5 = cursor.fetchall()
print(q5)
# Out:
# [(2,), (3,), (5,), (9,), (12,), (13,), (15,), (17,), (22,), (25,), (28,), (29,), (30,), (32,), (33,), (34,), (36,), (38,), (46,), (48,), (49,), (51,), (52,), (54,), (56,), (59,), (60,), (61,), (62,), (63,), (69,), (71,), (72,), (73,), (74,), (78,), (82,), (84,), (87,), (88,), (89,), (91,), (92,), (93,), (95,), (96,), (97,), (98,), (100,)]

# %%
# 6. Donner l’identifiant des clients n’ayant pas de livret A.
query = '''
SELECT idproprietaire, type
FROM compte
WHERE idproprietaire NOT IN(
SELECT idproprietaire FROM compte WHERE type = 'Livret A')
'''
q6 = pd.read_sql_query(query, bank_db)
q6
# Out:
#      idproprietaire                  type
# 0                70  Plan Epargne Actions
# 1                67         Assurance Vie
# 2                75        Compte Courant
# 3                 6         Assurance Vie
# 4                57        Compte Courant
# ..              ...                   ...
# 107              86        Compte Courant
# 108              27  Plan Epargne Actions
# 109              67        Compte Courant
# 110              83        Compte Courant
# 111              81  Plan Epargne Actions
#
# [112 rows x 2 columns]

# %%
# 7. Donner l’identifiant de compte et le type de compte des clients habitant à Paris.
query = '''
SELECT idcompte, type
FROM compte
WHERE idproprietaire IN
(SELECT idclient
FROM client
WHERE ville = 'Paris')
'''
q7 = pd.read_sql_query(query, bank_db)
q7
# Out:
#     idcompte                  type
# 0          9         Assurance Vie
# 1         60        Compte Courant
# 2         67        Compte Courant
# 3         77              Livret A
# 4         82  Plan Epargne Actions
# 5         91         Assurance Vie
# 6         98              Livret A
# 7        113         Assurance Vie
# 8        114        Compte Courant
# 9        125              Livret A
# 10       146         Assurance Vie
# 11       154         Assurance Vie
# 12       161         Assurance Vie
# 13       181              Livret A
# 14       183        Compte Courant
# 15       185        Compte Courant
# 16       200  Plan Epargne Actions
# 17       204  Plan Epargne Actions
# 18       219         Assurance Vie
# 19       233         Assurance Vie
# 20       234         Assurance Vie
# 21       242        Compte Courant
# 22       255        Compte Courant
# 23       261        Compte Courant
# 24       263         Assurance Vie
# 25       264        Compte Courant
# 26       278              Livret A
# 27       290         Assurance Vie
# 28       297              Livret A

# %%
# 8. Donner la liste des comptes et les types de compte de Dumbledore.
query = '''
SELECT idcompte, type
FROM compte
WHERE idproprietaire IN
(SELECT idclient FROM client
WHERE nom = 'Dumbledore')
'''
q8 = pd.read_sql_query(query, bank_db)
q8
# Out:
#    idcompte           type
# 0        65  Assurance Vie
# 1        71  Assurance Vie
# 2       214       Livret A
# 3       239       Livret A

# %%
# 9. Donner le nombre de clients par ville, classé par ordre alphabétique de villes.

# %%
# 10. Donner la ville ayant le plus de clients.

# %%
# 11. Trouver le nombre d’opérations effectuées sur chaque compte.

# %%
# 12. Trouver le nombre maximum d’opérations effectuées sur un compte.

# %%
# 13. Trouver le ou les numéros de compte réalisant le maximum de la question précédente.

# %%
# 14. Afficher, type par type, la moyenne des soldes des comptes (tous clients confondus) de chaque type (en supposant qu’initialement, les comptes sont tous vides).

# %%
# 15. Afficher, classé par nom et prénom, le nom, le prénom, le type de compte, et le solde, pour tous les comptes.

# %%
# 16. Même question, en se limitant aux clients dont le nom commence par K,L,M ou N.

# %%
# 17. Afficher le nom et le prénom des personnes ayant débité au moins un chèque sur leur compte courant, classé par nom.

# %%
# 18. Nom, prénom et ville de tous les clients ayant réalisé un nombre maximal d’opérations au guichet.

# %%
# 19. Moyenne par ville des fortunes totales des clients (somme sur tous leurs comptes), classé par valeur croissante.

# %%
# Fermer la connexion :
bank_db.close()

# %% [markdown]
# ## 4. Extraction en scrapant le web
#
# Récupérer la liste complète des députés de France ainsi que leurs adresses e-mail.
# Source: https://www.nosdeputes.fr/deputes

# %%
# Using modules Requests, BeautifulSoup and XPath
import requests
from bs4 import BeautifulSoup
from lxml import etree

URL = 'https://www.nosdeputes.fr/deputes'
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")

links = []
names = []
emails = []

# Get URL links of each deputy
tds = soup.findAll("td")
for td in tds:
  link = td.findAll("a")
  for a in link:
    link = a['href']
    links.append('https://www.nosdeputes.fr' + link)
print(links)

# # Test with the first deputy
# URL_DEPUTY = 'https://www.nosdeputes.fr/damien-abad'
# response = requests.get(URL_DEPUTY)
# soup = BeautifulSoup(response.text, "html.parser")
# name = soup.find("h1")
# print(name.text)
# dom = etree.HTML(str(soup))
# email = dom.xpath('//*[@id="b1"]/ul[2]/li[1]/ul/li[1]/a')[0]
# print(email.text)
  
# Get emails and names of each deputy in links
for i in links:
  response = requests.get(i)
  soup = BeautifulSoup(response.text, "html.parser")
  # Get name from h1
  name = soup.find("h1")
  names.append(name.text)
  # Get email using XPath
  dom = etree.HTML(str(soup))
  try:
    email = dom.xpath('//*[@id="b1"]/ul[2]/li[1]/ul/li[1]/a')[0]
    emails.append(email.text)
  except IndexError:
    emails.append(None)
print(names)
print(emails)
# Out:
# ['https://www.nosdeputes.fr/damien-abad', 'https://www.nosdeputes.fr/caroline-abadie', 'https://www.nosdeputes.fr/nadege-abomangoli', 'https://www.nosdeputes.fr/jean-felix-acquaviva', 'https://www.nosdeputes.fr/damien-adam', 'https://www.nosdeputes.fr/sabrina-agresti-roubache', 'https://www.nosdeputes.fr/eric-alauzet', 'https://www.nosdeputes.fr/xavier-albertini', 'https://www.nosdeputes.fr/laurent-alexandre', 'https://www.nosdeputes.fr/henri-alfandari', 'https://www.nosdeputes.fr/franck-allisio', 'https://www.nosdeputes.fr/gabriel-amard', 'https://www.nosdeputes.fr/david-amiel', 'https://www.nosdeputes.fr/segolene-amiot', 'https://www.nosdeputes.fr/farida-amrani', 'https://www.nosdeputes.fr/pieyre-alexandre-anglade', 'https://www.nosdeputes.fr/emmanuelle-anthoine', 'https://www.nosdeputes.fr/jean-philippe-ardouin', 'https://www.nosdeputes.fr/rodrigo-arenas', 'https://www.nosdeputes.fr/antoine-armand', 'https://www.nosdeputes.fr/christine-arrighi', 'https://www.nosdeputes.fr/gabriel-attal', 'https://www.nosdeputes.fr/clementine-autain', 'https://www.nosdeputes.fr/benedicte-auzanot', 'https://www.nosdeputes.fr/joel-aviragnet', 'https://www.nosdeputes.fr/anne-laure-babault', 'https://www.nosdeputes.fr/erwan-balanant', 'https://www.nosdeputes.fr/philippe-ballard', 'https://www.nosdeputes.fr/geraldine-bannier', 'https://www.nosdeputes.fr/christian-baptiste', 'https://www.nosdeputes.fr/jean-noel-barrot', 'https://www.nosdeputes.fr/christophe-barthes', 'https://www.nosdeputes.fr/nathalie-bassire', 'https://www.nosdeputes.fr/quentin-bataillon', 'https://www.nosdeputes.fr/delphine-batho', 'https://www.nosdeputes.fr/marie-noelle-battistel', 'https://www.nosdeputes.fr/xavier-batut', 'https://www.nosdeputes.fr/romain-baubry', 'https://www.nosdeputes.fr/julien-bayou', 'https://www.nosdeputes.fr/thibault-bazin', 'https://www.nosdeputes.fr/valerie-bazin-malgras', 'https://www.nosdeputes.fr/clement-beaune', 'https://www.nosdeputes.fr/jose-beaurain', 'https://www.nosdeputes.fr/olivier-becht', 'https://www.nosdeputes.fr/belkhir-belhaddad', 'https://www.nosdeputes.fr/mounir-belhamiti', 'https://www.nosdeputes.fr/beatrice-bellamy', 'https://www.nosdeputes.fr/lisa-belluco', 'https://www.nosdeputes.fr/karim-ben-cheikh', 'https://www.nosdeputes.fr/thierry-benoit', 'https://www.nosdeputes.fr/christophe-bentz', 'https://www.nosdeputes.fr/fanta-berete', 'https://www.nosdeputes.fr/anne-bergantz', 'https://www.nosdeputes.fr/aurore-berge', 'https://www.nosdeputes.fr/ugo-bernalicis', 'https://www.nosdeputes.fr/philippe-berta', 'https://www.nosdeputes.fr/pierrick-berteloot', 'https://www.nosdeputes.fr/herve-berville', 'https://www.nosdeputes.fr/veronique-besse', 'https://www.nosdeputes.fr/christophe-bex', 'https://www.nosdeputes.fr/bruno-bilde', 'https://www.nosdeputes.fr/carlos-martens-bilongo', 'https://www.nosdeputes.fr/emmanuel-blairy', 'https://www.nosdeputes.fr/sophie-blanc', 'https://www.nosdeputes.fr/christophe-blanchet', 'https://www.nosdeputes.fr/anne-laure-blin', 'https://www.nosdeputes.fr/frederic-boccaletti', 'https://www.nosdeputes.fr/philippe-bolo', 'https://www.nosdeputes.fr/manuel-bompard', 'https://www.nosdeputes.fr/emilie-bonnivard', 'https://www.nosdeputes.fr/jean-yves-bony', 'https://www.nosdeputes.fr/benoit-bordat', 'https://www.nosdeputes.fr/pascale-bordes', 'https://www.nosdeputes.fr/elisabeth-borne', 'https://www.nosdeputes.fr/eric-bothorel', 'https://www.nosdeputes.fr/ian-boucard', 'https://www.nosdeputes.fr/florent-boudie', 'https://www.nosdeputes.fr/mickael-bouloux', 'https://www.nosdeputes.fr/chantal-bouloux', 'https://www.nosdeputes.fr/idir-boumertit', 'https://www.nosdeputes.fr/jean-luc-bourgeaux', 'https://www.nosdeputes.fr/jean-louis-bourlanges', 'https://www.nosdeputes.fr/soumya-bourouaha', 'https://www.nosdeputes.fr/bertrand-bouyx', 'https://www.nosdeputes.fr/jorys-bovet', 'https://www.nosdeputes.fr/louis-boyard', 'https://www.nosdeputes.fr/pascale-boyer', 'https://www.nosdeputes.fr/yael-braun-pivet', 'https://www.nosdepu ...
# ['Damien Abad', 'Caroline Abadie', 'Nadège Abomangoli', 'Jean-Félix Acquaviva', 'Damien Adam', 'Sabrina Agresti-Roubache', 'Éric Alauzet', 'Xavier Albertini', 'Laurent Alexandre', 'Henri Alfandari', 'Franck Allisio', 'Gabriel Amard', 'David Amiel', 'Ségolène Amiot', 'Farida Amrani', 'Pieyre-Alexandre Anglade', 'Emmanuelle Anthoine', 'Jean-Philippe Ardouin', 'Rodrigo Arenas', 'Antoine Armand', 'Christine Arrighi', 'Gabriel Attal', 'Clémentine Autain', 'Bénédicte Auzanot', 'Jo